# %% [markdown]
# <a href="https://colab.research.google.com/github/matheus964-coder/Exerc-cios-em-Python/blob/main/Exercic%C3%ADos_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# começando do zero de python

# %% [markdown]
# inicial: "   matheus CALLado  fernandes     "<BR>
# final: "MATHEUS CALLADO FERNANDES"

# %%
texto = "   matheus CALLado  fernandes     "

# %%
print(texto.lower())
# Out:
#    matheus callado  fernandes

# %%
print(texto.upper())
# Out:
#    MATHEUS CALLADO  FERNANDES

# %%
print(texto.strip())
# Out:
# matheus CALLado  fernandes

# %%
print(texto.replace("  "," "))
# Out:
#   matheus CALLado fernandes

# %%
print(texto.strip().replace("  "," ").upper())
# Out:
# MATHEUS CALLADO FERNANDES

# %%
nome = input("digite seu nome: ")
# Out:
# digite seu nome: matheus

# %%
idade = input("digite sua idade: ")
# Out:
# digite sua idade: 17

# %%
print(f"meu nome é {nome} e tenho {idade} anos")
# Out:
# meu nome é matheus e tenho 17 anos

# %%
nome = input("Digite o seu nome: ")
# Out:
# Digite o seu nome: carlos

# %%
idade = int(input("Digite a sua idade: "))
# Out:
# Digite a sua idade: 16

# %%
if idade >= 18:
    print(f"{nome} pode entrar na festa porque ele é maior de idade.")
    print(f"Ele tem {idade} anos de idade.")
else:
    print(f"{nome} NÃO pode entrar na festa porque ele é menor de idade.")
    print(f"Ele tem {idade} anos de idade.")
# Out:
# carlos NÃO pode entrar na festa porque ele é menor de idade.
# Ele tem 16 anos de idade.

# %%
media = float(input("Digite a sua média: "))
# Out:
# Digite a sua média: 9

# %%
if media >= 7.0:
    print("Aprovado!")
elif media >= 5.0:
    print("Recuperação")
else:
    print("Reprovado!")
# Out:
# Aprovado!

# %%
if media < 5.0:
    print("Reprovado!")
elif media >= 5.0:
    print("Recuperação")
else:
    print("Aprovado!")
# Out:
# Recuperação

# %%
if media < 5.0:
    print("Reprovado!")
elif media >= 5.0 and media < 7.0:
    print("Recuperação")
else:
    print("Aprovado!")
# Out:
# Aprovado!

# %% [markdown]
# # loops e repeticao

# %%
n = 1

while n <= 10:
  print("*")
  n = n + 1
# Out:
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *

# %%
lista_de_nomes = ["Maria Silva", "João Santos", "Ana Oliveira", "Pedro Costa", "Juliana Pereira"]

# %%
print(lista_de_nomes[3])
# Out:
# Pedro Costa

# %%
lista_de_medias = [8.9, 7.5, 4.2, 1.4, 9.5]
print(lista_de_medias[3])
# Out:
# 1.4

# %%
lista_de_medias = [8.9, 7.5, 4.2, 1.4, 9.5]

n = 0
while n < 5:
    lista_de_medias[n] = lista_de_medias[n] + 1.0
    if lista_de_medias[n] > 10.0:
        lista_de_medias[n] = 10.0
    n = n + 1

print(lista_de_medias)
# Out:
# [9.9, 8.5, 5.2, 2.4, 10.0]

# %% [markdown]
# DICIONÁRIOS<BR> "chave":valor

# %%
lista_de_nomes = ["Mari Silvaa ", "João Santos", "Ana Oliveira", "Pedro Costa", "Juliana Pereira"]
lista_de_medias = [8.9, 7.5, 4.2, 1.4, 9.5]

# %%
dict_de_nomes_e_media = {"Mari Silvaa":8.9,
                         "João Santos":7.5,
                         "Ana Oliveira":4.2,
                         "Pedro Costa":1.4,
                         "Juliana Pereira":9.5}

# %%
dict_de_nomes_e_media['Mari Silvaa']
# Out:
# 8.9

# %%
altura = input("digite a sua altura em cm:")
# Out:
# digite a sua altura em cm:180

# %%
if float(altura) >= 180:
  print("alto")
elif float(altura) >= 170:
  print("media")
else:
  print("estátura baixa")
# Out:
# alto

# %%
dict_de_nomes_e_media.keys()
# Out:
# dict_keys(['Mari Silvaa', 'João Santos', 'Ana Oliveira', 'Pedro Costa', 'Juliana Pereira'])

# %%
dict_de_nomes_e_media.values()
# Out:
# dict_values([8.9, 7.5, 4.2, 1.4, 9.5])

# %%
dict_de_nomes_e_media.items()
# Out:
# dict_items([('Mari Silvaa', 8.9), ('João Santos', 7.5), ('Ana Oliveira', 4.2), ('Pedro Costa', 1.4), ('Juliana Pereira', 9.5)])

# %% [markdown]
# desafio

# %%
dict_desafio = [
    {"nome":"Mari Silvaa", "media":8.9},
    {"nome":"João Santos", "media":7.5},
    {"nome":"Ana Oliveira", "media":4.2},
    {"nome":"Pedro Costa", "media":1.4},
    {"nome":"Juliana Pereira", "media":9.5}
]

# %%
dict_desafio[0]
# Out:
# {'nome': 'Mari Silvaa', 'media': 8.9}

# %%
dict_desafio[3]
# Out:
# {'nome': 'Pedro Costa', 'media': 1.4}

# %%
for n in dict_desafio:
  print(n)
# Out:
# {'nome': 'Mari Silvaa', 'media': 8.9}
# {'nome': 'João Santos', 'media': 7.5}
# {'nome': 'Ana Oliveira', 'media': 4.2}
# {'nome': 'Pedro Costa', 'media': 1.4}
# {'nome': 'Juliana Pereira', 'media': 9.5}
